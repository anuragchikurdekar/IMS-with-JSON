# %%
import json

# %%
fd=open("Inventory.json","r")
a=fd.read()
fd.close()

# %%
a
# Out:
# '{"100": {"Product Name": "Cadbury milk chocolate", "Quantity Available": 200, "Price": "Rs 25", "Weight": "25 gm", "Packing Date": "5 SEP 2021", "Best Before": "3 MONTHS"}, "101": {"Product Name": "snickers", "Quantity Available": 150, "Price": "Rs 10", "Weight": "5 gm", "Packing Date": "14 AUG 2021", "Best Before": "3 MONTHS"}, "102": {"Product Name": "dairymilk", "Quantity Available": 250, "Price": "Rs 20", "Weight": "15 gm", "Packing Date": "10 MAY  2021", "Best Before": "3 MONTHS"}, "103": {"Product Name": "kit kat", "Quantity Available": 120, "Price": "Rs 10", "Weight": "7.5 gm", "Packing Date": "6 OCT 2020", "Best Before": "3 MONTHS"}, "104": {"Product Name": "Chocolate Modak", "Quantity Available": 50, "Price": "Rs 75", "Weight": "50 gm", "Packing Date": "10 SEP 2021", "Best Before": "3 MONTHS"}, "105": {"Product Name": "Cadbury dry fruit Chocolate", "Quantity Available": 100, "Price": "Rs 50", "Weight": "10 gm", "Packing Date": "5 JUNE 2021", "Best Before": "3 MONTHS"}, "106
# ...

# %%
inven=json.loads(a)

# %%
inven
# Out:
# {'100': {'Best Before': '3 MONTHS',
#   'Packing Date': '5 SEP 2021',
#   'Price': 'Rs 25',
#   'Product Name': 'Cadbury milk chocolate',
#   'Quantity Available': 200,
#   'Weight': '25 gm'},
#  '101': {'Best Before': '3 MONTHS',
#   'Packing Date': '14 AUG 2021',
#   'Price': 'Rs 10',
#   'Product Name': 'snickers',
#   'Quantity Available': 150,
#   'Weight': '5 gm'},
#  '102': {'Best Before': '3 MONTHS',
#   'Packing Date': '10 MAY  2021',
#   'Price': 'Rs 20',
#   'Product Name': 'dairymilk',
#   'Quantity Available': 250,
#   'Weight': '15 gm'},
#  '103': {'Best Before': '3 MONTHS',
#   'Packing Date': '6 OCT 2020',
#   'Price': 'Rs 10',
#   'Product Name': 'kit kat',
#   'Quantity Available': 120,
#   'Weight': '7.5 gm'},
#  '104': {'Best Before': '3 MONTHS',
#   'Packing Date': '10 SEP 2021',
#   'Price': 'Rs 75',
#   'Product Name': 'Chocolate Modak',
#   'Quantity Available': 50,
#   'Weight': '50 gm'},
#  '105': {'Best Before': '3 MONTHS',
# ...

# %%
inven["141"]={"Best Before":"6 MONTHS","Packing Date":"25 OCT 2020","Price":"Rs 50","Product Name":"Nestle Coffee","Quantity Available":"25","Weight":"100 gm"}

# %%
inven
# Out:
# {'100': {'Best Before': '3 MONTHS',
#   'Packing Date': '5 SEP 2021',
#   'Price': 'Rs 25',
#   'Product Name': 'Cadbury milk chocolate',
#   'Quantity Available': 200,
#   'Weight': '25 gm'},
#  '101': {'Best Before': '3 MONTHS',
#   'Packing Date': '14 AUG 2021',
#   'Price': 'Rs 10',
#   'Product Name': 'snickers',
#   'Quantity Available': 150,
#   'Weight': '5 gm'},
#  '102': {'Best Before': '3 MONTHS',
#   'Packing Date': '10 MAY  2021',
#   'Price': 'Rs 20',
#   'Product Name': 'dairymilk',
#   'Quantity Available': 250,
#   'Weight': '15 gm'},
#  '103': {'Best Before': '3 MONTHS',
#   'Packing Date': '6 OCT 2020',
#   'Price': 'Rs 10',
#   'Product Name': 'kit kat',
#   'Quantity Available': 120,
#   'Weight': '7.5 gm'},
#  '104': {'Best Before': '3 MONTHS',
#   'Packing Date': '10 SEP 2021',
#   'Price': 'Rs 75',
#   'Product Name': 'Chocolate Modak',
#   'Quantity Available': 50,
#   'Weight': '50 gm'},
#  '105': {'Best Before': '3 MONTHS',
# ...

# %%
Product_ID=str(int(input()))
Product_Name=str(input())
Price=("Rs " + str(input()))
Quantity_Available=int(input())
Weight=str(input())
Packing_Date=str(input())
Best_Before=str(input())

inven[Product_ID] = {"Product Name":Product_Name,"Price":Price,"Quantity Available":Quantity_Available,"Weight":Weight,"Packing Date":Packing_Date,"Best Before":Best_Before}
# Out:
# 142
# Tea
# 50
# 20
# 50 gm
# 20 JUNE 2021
# 6 MONTHS

# %%
inven
# Out:
# {'100': {'Best Before': '3 MONTHS',
#   'Packing Date': '5 SEP 2021',
#   'Price': 'Rs 25',
#   'Product Name': 'Cadbury milk chocolate',
#   'Quantity Available': 200,
#   'Weight': '25 gm'},
#  '101': {'Best Before': '3 MONTHS',
#   'Packing Date': '14 AUG 2021',
#   'Price': 'Rs 10',
#   'Product Name': 'snickers',
#   'Quantity Available': 150,
#   'Weight': '5 gm'},
#  '102': {'Best Before': '3 MONTHS',
#   'Packing Date': '10 MAY  2021',
#   'Price': 'Rs 20',
#   'Product Name': 'dairymilk',
#   'Quantity Available': 250,
#   'Weight': '15 gm'},
#  '103': {'Best Before': '3 MONTHS',
#   'Packing Date': '6 OCT 2020',
#   'Price': 'Rs 10',
#   'Product Name': 'kit kat',
#   'Quantity Available': 120,
#   'Weight': '7.5 gm'},
#  '104': {'Best Before': '3 MONTHS',
#   'Packing Date': '10 SEP 2021',
#   'Price': 'Rs 75',
#   'Product Name': 'Chocolate Modak',
#   'Quantity Available': 50,
#   'Weight': '50 gm'},
#  '105': {'Best Before': '3 MONTHS',
# ...

# %%
inven=json.dumps(inven)

# %%
x=open("Added_products_inventory.json","w")
x.write(inven)
x.close()
